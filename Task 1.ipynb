# %%
# Step 1: Import pandas
import pandas as pd
df = pd.read_csv(r"C:\Users\mungi\Downloads\KaggleV2-May-2016.csv\KaggleV2-May-2016.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
print(df.isnull().sum())
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df['Gender'] = df['Gender'].str.lower().str.strip()

# Optional: Replace common inconsistencies
df['Gender'] = df['Gender'].replace({
    'female': 'f',
    'male': 'm',
    'woman': 'f',
    'man': 'm'
})
df['Gender']
# Out:
# 0         f
# 1         m
# 2         f
# 3         f
# 4         f
#          ..
# 110522    f
# 110523    f
# 110524    f
# 110525    f
# 110526    f
# Name: Gender, Length: 110527, dtype: object

# %%
df.dtypes
# Out:
# PatientId         float64
# AppointmentID       int64
# Gender             object
# ScheduledDay       object
# AppointmentDay     object
# Age                 int64
# Neighbourhood      object
# Scholarship         int64
# Hipertension        int64
# Diabetes            int64
# Alcoholism          int64
# Handcap             int64
# SMS_received        int64
# No-show            object
# dtype: object

# %%
df.shape
# Out:
# (110527, 14)

# %%
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay'], errors='coerce', dayfirst=True)
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay'], errors='coerce', dayfirst=True)

# %%
# Separate ScheduledDay
df['scheduled_date'] = df['ScheduledDay'].dt.date
df['scheduled_time'] = df['ScheduledDay'].dt.time

# Separate AppointmentDay
df['appointment_date'] = df['AppointmentDay'].dt.date
df['appointment_time'] = df['AppointmentDay'].dt.time
df['appointment_date']
# Out:
# 0         2016-04-29
# 1         2016-04-29
# 2         2016-04-29
# 3         2016-04-29
# 4         2016-04-29
#              ...
# 110522    2016-06-07
# 110523    2016-06-07
# 110524    2016-06-07
# 110525    2016-06-07
# 110526    2016-06-07
# Name: appointment_date, Length: 110527, dtype: object

# %%
df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      f 2016-04-29 18:38:08+00:00
# 1       5.589978e+14        5642503      m 2016-04-29 16:08:27+00:00
# 2       4.262962e+12        5642549      f 2016-04-29 16:19:04+00:00
# 3       8.679512e+11        5642828      f 2016-04-29 17:29:31+00:00
# 4       8.841186e+12        5642494      f 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572134e+12        5651768      f 2016-05-03 09:15:35+00:00
# 110523  3.596266e+12        5650093      f 2016-05-03 07:27:33+00:00
# 110524  1.557663e+13        5630692      f 2016-04-27 16:03:52+00:00
# 110525  9.213493e+13        5630323      f 2016-04-27 15:09:23+00:00
# 110526  3.775115e+14        5629448      f 2016-04-27 13:30:56+00:00
#
#        AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# ...

# %%
#chatgpt dataset
import pandas as pd
df=pd.read_csv(r"C:\Users\mungi\Downloads\sample_dirty_data.csv")
df
# Out:
#       Name      Age   Gender                 Email    JoinDate   Salary
# 0    Alice       25   Female     alice@example.com  2021-01-15    50000
# 1      Bob       30     Male       bob@example.com  2020-06-30    60000
# 2  Charlie      NaN     Male                   NaN  not a date    55000
# 3    David       45      NaN         david@example  2019/12/01      NaN
# 4      Eve  Unknown   Female       eve@example.com         NaN      NaN
# 5      NaN       50   Female       eve@example.com  2022-07-25    65000
# 6    Frank       35     Male  frank[at]example.com  2021-13-01    62000
# 7    Grace      NaN  Unknown                   NaN  2020-05-10    58000
# 8    Heidi       29        F     heidi@example.com  2021-08-30  unknown
# 9     Ivan       40        M      ivan@example.com         NaN    70000

# %%
df.shape
# Out:
# (10, 6)

# %%
df.dtypes
# Out:
# Name        object
# Age         object
# Gender      object
# Email       object
# JoinDate    object
# Salary      object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Name        1
# Age         2
# Gender      1
# Email       2
# JoinDate    2
# Salary      2
# dtype: int64

# %%
#filled null in age with median of age column
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')  # ensure numeric
df['Age'] = df['Age'].fillna(df['Age'].median())
df
# Out:
#       Name   Age   Gender                 Email    JoinDate   Salary
# 0    Alice  25.0   Female     alice@example.com  2021-01-15    50000
# 1      Bob  30.0     Male       bob@example.com  2020-06-30    60000
# 2  Charlie  35.0     Male                   NaN  not a date    55000
# 3    David  45.0      NaN         david@example  2019/12/01      NaN
# 4      Eve  35.0   Female       eve@example.com         NaN      NaN
# 5      NaN  50.0   Female       eve@example.com  2022-07-25    65000
# 6    Frank  35.0     Male  frank[at]example.com  2021-13-01    62000
# 7    Grace  35.0  Unknown                   NaN  2020-05-10    58000
# 8    Heidi  29.0        F     heidi@example.com  2021-08-30  unknown
# 9     Ivan  40.0        M      ivan@example.com         NaN    70000

# %%
#filled null in date with random date
df['JoinDate'] = pd.to_datetime(df['JoinDate'], errors='coerce')
df['JoinDate'] = df['JoinDate'].fillna(pd.to_datetime("2000-01-01"))
df
# Out:
#       Name   Age   Gender                 Email   JoinDate   Salary
# 0    Alice  25.0   Female     alice@example.com 2021-01-15    50000
# 1      Bob  30.0     Male       bob@example.com 2020-06-30    60000
# 2  Charlie  35.0     Male                   NaN 2000-01-01    55000
# 3    David  45.0      NaN         david@example 2000-01-01      NaN
# 4      Eve  35.0   Female       eve@example.com 2000-01-01      NaN
# 5      NaN  50.0   Female       eve@example.com 2022-07-25    65000
# 6    Frank  35.0     Male  frank[at]example.com 2000-01-01    62000
# 7    Grace  35.0  Unknown                   NaN 2020-05-10    58000
# 8    Heidi  29.0        F     heidi@example.com 2021-08-30  unknown
# 9     Ivan  40.0        M      ivan@example.com 2000-01-01    70000

# %%
# Ensuring the column is numeric
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')
# Filled nulls with the minimum salary
df['Salary'] = df['Salary'].fillna(df['Salary'].min())
df
# Out:
#       Name   Age   Gender                 Email   JoinDate   Salary
# 0    Alice  25.0   Female     alice@example.com 2021-01-15  50000.0
# 1      Bob  30.0     Male       bob@example.com 2020-06-30  60000.0
# 2  Charlie  35.0     Male                   NaN 2000-01-01  55000.0
# 3    David  45.0      NaN         david@example 2000-01-01  50000.0
# 4      Eve  35.0   Female       eve@example.com 2000-01-01  50000.0
# 5      NaN  50.0   Female       eve@example.com 2022-07-25  65000.0
# 6    Frank  35.0     Male  frank[at]example.com 2000-01-01  62000.0
# 7    Grace  35.0  Unknown                   NaN 2020-05-10  58000.0
# 8    Heidi  29.0        F     heidi@example.com 2021-08-30  50000.0
# 9     Ivan  40.0        M      ivan@example.com 2000-01-01  70000.0

# %%
#changed datatypes
df['Age'] = df['Age'].astype(int)
df['Salary'] = df['Salary'].astype(int)
df.dtypes
# Out:
# Name                object
# Age                  int32
# Gender              object
# Email               object
# JoinDate    datetime64[ns]
# Salary               int32
# dtype: object

# %%
#dropped the email which had null
df = df.dropna(subset=['Email'])
df
# Out:
#     Name  Age  Gender                 Email   JoinDate  Salary
# 0  Alice   25  Female     alice@example.com 2021-01-15   50000
# 1    Bob   30    Male       bob@example.com 2020-06-30   60000
# 3  David   45     NaN         david@example 2000-01-01   50000
# 4    Eve   35  Female       eve@example.com 2000-01-01   50000
# 5    NaN   50  Female       eve@example.com 2022-07-25   65000
# 6  Frank   35    Male  frank[at]example.com 2000-01-01   62000
# 8  Heidi   29       F     heidi@example.com 2021-08-30   50000
# 9   Ivan   40       M      ivan@example.com 2000-01-01   70000

# %%
import numpy as np
df['Gender'] = df['Gender'].replace({
    'M': 'Male',
    'F': 'Female',
    'Unknown': 'Female'
})
# Replace actual NaN (not string) with a value (e.g., 'Male')
df['Gender'] = df['Gender'].fillna('Male')
df
# Out:
# C:\Users\mungi\AppData\Local\Temp\ipykernel_14004\2081658853.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace({
# C:\Users\mungi\AppData\Local\Temp\ipykernel_14004\2081658853.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].fillna('Male')
#     Name  Age  Gender                 Email   JoinDate  Salary
# 0  Alice   25  Female     alice@example.com 2021-01-15   50000
# ...

# %%
df = df.copy()  # to avoid SettingWithCopyWarning

df['Gender'] = df['Gender'].replace({
    'M': 'Male',
    'F': 'Female',
    'Unknown': 'Female'
}).fillna('Male')
df
# Out:
#     Name  Age  Gender                 Email   JoinDate  Salary
# 0  Alice   25  Female     alice@example.com 2021-01-15   50000
# 1    Bob   30    Male       bob@example.com 2020-06-30   60000
# 3  David   45    Male         david@example 2000-01-01   50000
# 4    Eve   35  Female       eve@example.com 2000-01-01   50000
# 5    NaN   50  Female       eve@example.com 2022-07-25   65000
# 6  Frank   35    Male  frank[at]example.com 2000-01-01   62000
# 8  Heidi   29  Female     heidi@example.com 2021-08-30   50000
# 9   Ivan   40    Male      ivan@example.com 2000-01-01   70000

# %%
df['Name'] = df['Name'].fillna('Unknown')
df
# Out:
#       Name  Age  Gender                 Email   JoinDate  Salary
# 0    Alice   25  Female     alice@example.com 2021-01-15   50000
# 1      Bob   30    Male       bob@example.com 2020-06-30   60000
# 3    David   45    Male         david@example 2000-01-01   50000
# 4      Eve   35  Female       eve@example.com 2000-01-01   50000
# 5  Unknown   50  Female       eve@example.com 2022-07-25   65000
# 6    Frank   35    Male  frank[at]example.com 2000-01-01   62000
# 8    Heidi   29  Female     heidi@example.com 2021-08-30   50000
# 9     Ivan   40    Male      ivan@example.com 2000-01-01   70000
